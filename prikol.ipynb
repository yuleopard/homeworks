# %% [markdown]
# ### Задание №1
# Скачайте текст "Литературных анекдотов". Напишите функцию, которая будет читать файл, лемматизировать текст с помощью pymystem3 и записывать результат в новый файл. У функции должно бы два аргумента: путь к исходному файлу и путь к файлу с лемматизированным текстом. Вызов функции тоже должен быть прописан в решении.

# %%
import os, re, json
from pymystem3 import Mystem
from collections import Counter

# %%
# Читаем файл с анекдотами
with open('telegram.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# Очищаем от пунктуации
text_clean = [w.strip("!\"#$%&'()*+,./:;<=>?@[\]^_`{|}~„“«»†*—/\-—") for w in text.split()] 
text_clean = [w for w in text_clean if len(w) != 0] # очищаем от пустых элементов
text_clean = ' '.join(text_clean) # соединяем в строку

#Лемматизируем
m = Mystem()
lemmas = m.lemmatize(text_clean)
text_lemma = ''.join(lemmas) # соединяем в строку

# %%
lemmas_to_file(input("Введите путь к исходному файлу\n"), input("Задайте имя конечного файла\n"))
# Out:
# Введите путь к исходному файлу
# literary_anecdotes.txt
# Задайте имя конечного файла
# lemmatized.txt
# 'у вяземский быть квартира окно на тверской бульвар пушкин очень любить ходить к он в гость прийти и сразу прыг на подоконник свешиваться из окно и смотреть чай он тоже туда на окно подавать иной раз там и заночевать он даже матрац купить специальный только он он не признавать."к что говорить такой роскошь и спихивать матрац с подоконник а потом весь ночь вертеться спать не давать гоголь переодеваться пушкин приходить к пушкин и позвонить пушкин открывать он и кричать смотреть арина родионовна я приходить лермонтов хотеть у пушкин жена уводить на кавказ все смотреть на она из-за колонна смотреть вдруг устыжаться свой желание пушкин думать зеркало русский революция а я свинья пойти вставать перед он на колено и говорить пушкин где твой кинжал вот грудь мой пушкин очень смеяться однажды пушкин стреляться с гоголь пушкин говорить стрелять первый ты как я нет ты ах я нет ты так и не становиться стреляться лев толстой очень любить ребенок однажды он идти по тверской бульвар и увидеть впереди пушкин конечно это уже не ребенок это уже подросток подумать лев толстой все равный давать догнать и погладить по головка и побежать догонять пушкин пушкин же не знать толстовский намерение бросаться наутек пробегать мимо городовой сей страж порядок быть возмущать неприличный быстрота бега в людный место и бегом устремляться вслед с цель останавливать западный пресса потом писать что в россия литератор подвергаться преследование со сторона власть однажды лермонтов купить яблоко приходить на тверской бульвар и становиться угощать присутствовать дама все брать и говорить мерси когда же подходить наталья николаевна с сестра александрина от волнение он так задрожать что яблоко упасть к она нога наталья николаевна а не александрина один из собака схватывать яблоко и бросаться бежать александрин конечно побежать за она они быть один впервые в жизнь лермонтов конечно а не александрин с собачка кстати она александрин она не догнать однажды пушкин решать испугать тургенев и спрятаться на тверской бульвар под лавка а гоголь тоже решать в этот день испугать тургенев переодеваться пушкин и спрятаться под другой лавка тут тургенев идти как они оба выскочить лев толстой очень любить ребенок однажды он играть с они весь день и проголодаться сонечка говорить а ангелочек сделать я тюрька она возражать левушка ты же видеть я война и мир переписывать а-а-а возопить он так я и знать что ты мой литературный фимиам дорогой мой я и костыль задрожать в его судорожный рука однажды пушкин написать письмо рабиндранат тагор дорогой далекий друг писать он я вы не знать и вы я не знать очень хотеться бы познакомиться все хороший саша когда письмо приносить тагор предаваться самосозерцание так погружаться хоть резать его жена толкать толкать письмо подсовывать не видеть он правда по-русски читать не уметь так и не познакомиться однажды федор михайлович достоевский царствие он небесный исполняться 150 год он очень обрадоваться и устраивать день рождение приходить к он все писатель только почему-то все наголо обривать у один гоголь ус нарисовать ну хорошо выпивать закусывать поздравлять новорожденный царствие он небесный садиться играть в вист сдавать лев толстой у каждый по пять туз что за черт так не бывать сдавать-ка брат пушкин хорошо ты я говорить пожалуйста сдавать и сдавать у каждый по шесть туз и по два пиковый дама ну и дело сдавать-ка ты брат гоголь гоголь сдавать ну знать даже и нехорошо сказать как-то получаться так нет право хороший не надо однажды федор михайлович достоевский царствие он небесный сидеть у окно и курить докуривать и выбрасывать окурок из окно под окно у он быть керосиновый лавка и окурок угождать как раз в бидон с керосин пламень конечно столб в один ночь пол-петербург сгорать ну посадить он конечно отсиживать выходить идти в первый же день по петербург навстречу петрашевский ничто он не сказать только пожимать рука и в глаз посмотреть со значение сниться однажды герцен сон будто иммигрировать он в лондон и житься он там очень хорошо купить он буд ...

# %% [markdown]
# ### Задание №2
# Очистите лемматизированный текст от стоп-слов и посчитайте ipm для оставшихся. Выведите 20 самых частотных по этому параметру слов.

# %%
# Очищаем от стоп слов

# Открываем файл со стоп-словами
with open('rus_stopwords.txt', 'r', encoding='utf-8') as f:
    stopwords = f.read()
    
# делаем список по переносу строки
stopwords = stopwords.split('\n')

# в новый список все слова, кроме стоп слов
text_nosw = [w for w in text_lemma.split() if w not in stopwords if w.isalpha()] 


# Считаем ipm для оставшихся. Создаем словарь, в который это будет записываться, считаем абсолютную частоту каунтером, записываем в новый словарь ключ из каунтера, а значение делим на длину текста и умножаем на 100000
text_ipm = {}
counts = Counter(text_nosw)

for k, v in counts.items():
    text_ipm[k] = (v/len(story.split()))*1000000
    

# Сортируем и выводим 20 самых частотных
sorted_ipm = sorted(text_ipm.items(), key=lambda x: x[1], reverse=True)
sorted_ipm[:100]
# Out:
# [('андрей', 316514.0472185885),
#  ('юлец', 314582.94399800664),
#  ('yuleopard', 314582.94399800664),
#  ('pechenyshki', 314333.76938889927),
#  ('Photo', 41799.040677754936),
#  ('size', 34635.27066591914),
#  ('bytes', 34635.27066591914),
#  ('FWD', 24232.23073568803),
#  ('че', 21678.19099233788),
#  ('Voice', 10776.801843892108),
#  ('Message', 10776.801843892108),
#  ('Video', 10589.92088706161),
#  ('тип', 9655.516102909112),
#  ('суп', 8285.055752818787),
#  ('щас', 7911.29383915779),
#  ('ока', 7911.29383915779),
#  ('блин', 7662.119230050458),
#  ('просто', 6914.5954027284615),
#  ('ета', 6727.714445897963),
#  ('хз', 6167.071575406466),
#  ('какой', 5731.016009468635),
#  ('бля', 5170.373138977138),
#  ('давать', 5170.373138977138),
#  ('сделать', 4858.904877592973),
#  ('ахах', 4796.61122531614),
#  ('Sticker', 4734.317573039307),
#  ('Document', 4672.023920762474),
#  ('ага', 4235.968354824643),
#  ('кстати', 4173.674702547811),
#  ('знать', 4111.3810502709775),
#  ('лан', 3986.7937457173116),
#  ('ток', 3924.5000934404784),
#  ('купить', 3924.5000934404784),
#  ('аа', 3737.6191366099797),
#  ('потому', 3675.3254843331465),
#  ('ехать', 3613.0318320563138),
#  ('взять', 3550.73817977948),
#  ('посмотреть', 3488.4445275026474),
#  ('лола', 3363.8572229489814),
#  ('блять', 3363.8572229489814),
#  ('час', 3363.8572229489814),
#  ('твой', 3301.563570672148),
#  ('чувак', 3239.2699183953155),
#  ('GIF', 3176.9762661184823),
#  ('день', 3052.3889615648163),
#  ('хорошо', 2990.0953092879836),
#  ('тоже', 2927.801657011151),
#  ('написать', 2927.801657011151),
#  ('ща', 2927.801657011151),
#  ('кадр', 2927.801657011151),
#  ('понимать', 2865.5080047343176),
#  ('круто', 2865.5080047343176),
#  ('пока', 2865.5080047343176),
#  ('человек', 2803.214352457485),
#  ('два', 2803.214352457485),
#  ('тя', 2740.9207001806517),
#  ('скок', 2678.627047903819),
#  ('дома', 2616.3333956269857),
#  ('снимать', 2616.3333956269857),
#  ('время', 2616.3333956269857),
#  ('зайти', 2554.039743350153),
#  ('точно', 2491.7460910733193),
#  ('идти', 2491.7460910733193),
#  ('чето', 2491.7460910733193),
#  ('завтра', 2491.7460910733193),
#  ('норма', 2491.7460910733193),
#  ('ого', 2429.4524387964866),
#  ('много', 2429.4524387964866),
#  ('приезжать', 2429.4524387964866),
#  ('находить', 2367.1587865196534),
#  ('выходить', 2367.1587865196534),
#  ('капец', 2367.1587865196534),
#  ('помнить', 2304.8651342428207),
#  ('спрашивать', 2304.8651342428207),
#  ('приходить', 2242.5714819659875),
#  ('смотреть', 2242.5714819659875),
#  ('мак', 2242.5714819659875),
#  ('поехать', 2242.5714819659875),
#  ('вообще', 2242.5714819659875),
#  ('видео', 2242.5714819659875),
#  ('call', 2180.2778296891547),
#  ('работать', 2180.2778296891547),
#  ('минута', 2055.6905251354888),
#  ('нужный', 2055.6905251354888),
#  ('домой', 2055.6905251354888),
#  ('Anna', 2055.6905251354888),
#  ('неа', 1993.3968728586558),
#  ('комп', 1993.3968728586558),
#  ('Antonova', 1993.3968728586558),
#  ('пиздец', 1931.1032205818228),
#  ('спать', 1868.8095683049899),
#  ('вроде', 1868.8095683049899),
#  ('самый', 1868.8095683049899),
#  ('пара', 1868.8095683049899),
#  ('короче', 1868.8095683049899),
#  ('пойти', 1806.5159160281569),
#  ('мб', 1806.5159160281569),
#  ('наверное', 1806.5159160281569),
#  ('утро', 1744.2222637513237),
#  ('нить', 1744.2222637513237)]

# %% [markdown]
# ### Задание №3
# Сделайте полный морфологический разбор исходного текста. Напишите регулярное выражение, которое будет извлекать из тега только часть речи. Пройдитесь циклом по списку с разборами, который выдал pymystem3, извлекая из каждого разбора форму слова и его часть речи и записывая их в новый словарь (форма -- ключ, часть речи -- значение). Посчитайте абсолютную частоту для всех частей речи, а затем относительнную частоту (абсолютная частота / длина текста в словах).

# %%
# Открываем файл с исходным текстом
with open('wall.txt', 'r', encoding='utf-8') as f:
    story = f.read()

# Анализируем
story_analyzed = m.analyze(story)
 
# создаём словарь с только грамматикой
words = {}
for word in story_analyzed:
    try:
        form = word['text']
        grammar = word['analysis'][0]['gr']
        words[form] = grammar
    except KeyError:
        pass
    except IndexError:
        pass

# Компилируем регулярку для вытаскивания части речи
pos = re.compile('[A-Z]+')

# Делаем пустой словарь
words_pos = {}

# Добавляем в словарь ключ из предыдущего словаря и значение которое даёт регулярка
for k, v in words.items():
    words_pos[k] = pos.match(v).group(0)

# %%
words_pos
# Out:
# {'Нейросети': 'S',
#  'выводят': 'V',
#  'возможности': 'S',
#  'дубляжа': 'S',
#  'на': 'PR',
#  'новый': 'A',
#  'уровень': 'S',
#  'Видеозапись': 'S',
#  'Вы': 'SPRO',
#  'ноя': 'S',
#  'в': 'S',
#  'Ссылка': 'S',
#  'окт': 'S',
#  'моём': 'APRO',
#  'паблике': 'S',
#  'обновление': 'S',
#  'кстати': 'ADV',
#  'там': 'ADVPRO',
#  'понятно': 'ADV',
#  'что': 'CONJ',
#  'конце': 'S',
#  'шарик': 'S',
#  'улетает': 'V',
#  'юлец': 'S',
#  'ребята': 'S',
#  'рада': 'A',
#  'наконецто': 'ADV',
#  'вам': 'SPRO',
#  'представить': 'V',
#  'свой': 'APRO',
#  'проект': 'S',
#  'вообще-то': 'ADV',
#  'он': 'SPRO',
#  'предполагался': 'V',
#  'как': 'CONJ',
#  'тестовый': 'A',
#  'но': 'CONJ',
#  'почему-то': 'ADVPRO',
#  'всё': 'APRO',
#  'зашло': 'V',
#  'слишком': 'ADV',
#  'далеко': 'ADV',
#  'и': 'CONJ',
#  'я': 'SPRO',
#  'потратила': 'V',
#  'него': 'SPRO',
#  'больше': 'ADV',
#  'времени': 'S',
#  'чем': 'CONJ',
#  'планировала': 'V',
#  'смысла': 'S',
#  'нет': 'PART',
#  'саунддизайн': 'S',
#  'печенюшки': 'S',
#  'чёто': 'S',
#  'пивка': 'S',
#  'хочеца': 'S',
#  'Комментарии': 'S',
#  'обожаю': 'V',
#  'когда': 'CONJ',
#  'смешно': 'ADV',
#  'Внимание': 'S',
#  'ищу': 'V',
#  'кого-нибудь': 'SPRO',
#  'кто': 'SPRO',
#  'разбирается': 'V',
#  'танцах': 'S',
#  'знает': 'V',
#  'современных': 'A',
#  'русских': 'A',
#  'зарубежных': 'A',
#  'крутых': 'A',
#  'хореографов': 'S',
#  'или': 'CONJ',
#  'школы': 'S',
#  'просто': 'PART',
#  'сам': 'APRO',
#  'хорошо': 'A',
#  'танцует': 'V',
#  'Напишите': 'V',
#  'мне': 'SPRO',
#  'плиз': 'S',
#  'ну': 'PART',
#  'лафкните': 'V',
#  'сама': 'APRO',
#  'напишу': 'V',
#  'Макеева': 'S',
#  'Марина': 'S',
#  'МОЯ': 'APRO',
#  'Документ': 'S',
#  'Фотография': 'S',
#  'кто-нибудь': 'SPRO',
#  'когда-нибудь': 'ADVPRO',
#  'чувствовал': 'V',
#  'себя': 'SPRO',
#  'интересным': 'A',
#  'благодаря': 'PR',
#  'сен': 'S',
#  'Запись': 'S',
#  'удалена': 'V',
#  'делюсь': 'V',
#  'офигенной': 'A',
#  'штукой': 'S',
#  'подписывайтесь': 'V',
#  'мой': 'APRO',
#  'паблик': 'S',
#  'В': 'PR',
#  'маке': 'S',
#  'есть': 'V',
#  'встроенный': 'A',
#  'психотерапевт': 'S',
#  'бесплатно': 'ADV',
#  'откройте': 'V',
#  'терминал': 'S',
#  'напишите': 'V',
#  'нажмите': 'V',
#  'ентер': 'S',
#  'наберите': 'V',
#  'пробел': 'S',
#  'После': 'ADV',
#  'того': 'SPRO',
#  'вы': 'SPRO',
#  'закончили': 'V',
#  'свою': 'APRO',
#  'реплику': 'S',
#  'надо': 'ADV',
#  'нажать': 'V',
#  'два': 'NUM',
#  'раза': 'S',
#  'У': 'PR',
#  'меня': 'SPRO',
#  'вышел': 'V',
#  'вот': 'PART',
#  'такой': 'APRO',
#  'душевный': 'A',
#  'разговорчик': 'S',
#  'первая': 'ANUM',
#  'строчка': 'S',
#  'доктор': 'S',
#  'потом': 'ADVPRO',
#  'наши': 'APRO',
#  'реплики': 'S',
#  'чередуются': 'V',
#  'потеряла': 'V',
#  'карточницу': 'S',
#  'афигеть': 'V',
#  'люблю': 'V',
#  'жизни': 'S',
#  'это': 'SPRO',
#  'красота': 'S',
#  'приколы': 'S',
#  'чай': 'S',
#  'с': 'PR',
#  'бергамотом': 'S',
#  'у': 'PR',
#  'щас': 'ADV',
#  'первый': 'ANUM',
#  'раз': 'S',
#  'пошла': 'V',
#  'кровь': 'S',
#  'из': 'PR',
#  'носа': 'S',
#  'интерактивная': 'A',
#  'проекция': 'S',
#  'капец': 'S',
#  'респект': 'S',
#  'видосы': 'S',
#  'этого': 'SPRO',
#  'канала': 'S',
#  'показывать': 'V',
#  'всем': 'SPRO',
#  'обязательно': 'ADV',
#  'можно': 'ADV',
#  'так': 'ADVPRO',
#  'четко': 'ADV',
#  'точно': 'ADV',
#  'понимать': 'V',
#  'человека': 'S',
#  'ух': 'INTJ',
#  'мы': 'SPRO',
#  'вовремя': 'ADV',
#  'туда': 'ADVPRO',
#  'собрались': 'V',
#  'Лентач': 'S',
#  'Конституционный': 'A',
#  'суд': 'S',
#  'Грузии': 'S',
#  'легализовал': 'V',
#  'употребление': 'S',
#  'марихуаны': 'S',
#  'стране': 'S',
#  'июл': 'S',
#  'пиздец': 'S',
#  'Лера': 'S',
#  'Суханова': 'S',
#  'Вчера': 'ADV',
#  'утром': 'S',
#  'получила': 'V',
#  'письмо': 'S',
#  'угрозами': 'S',
#  'то': 'CONJ',
#  'же': 'PART',
#  'самое': 'APRO',
#  'ждёт': 'V',
#  'моих': 'APRO',
#  'друзей': 'S',
#  'Я': 'SPRO',
#  'скриншоты': 'S',
#  'вчерашних': 'A',
#  'кадров': 'S',
#  'А': 'CONJ',
#  'ещё': 'ADV',
#  'теперь': 'ADV',
#  'все': 'APRO',
#  'знают': 'V',
#  'за': 'PR',
#  'именно': 'PART',
#  'Статья': 'S',
#  'снова': 'ADV',
#  'провожу': 'V',
#  'небольшой': 'A',
#  'ресёрч': 'S',
#  'обращаюсь': 'V',
#  'к': 'PR',
#  'тем': 'CONJ',
#  'читает': 'V',
#  'экрана': 'S',
#  'каким': 'APRO',
#  'образом': 'S',
#  'делаете': 'V',
#  'читаете': 'V',
#  'абзац': 'S',
#  'прокручиваете': 'V',
#  'текст': 'S',
#  'след': 'S',
#  'кусочек': 'S',
#  'опять': 'ADV',
#  'начала': 'S',
#  'целиком': 'ADV',
#  'влезает': 'V',
#  'экран': 'S',
#  'следующий': 'A',
#  'Опрос': 'S',
#  'июн': 'S',
#  'нейроны': 'S',
#  'огромной': 'A',
#  'естественной': 'A',
#  'нейросети': 'S',
#  'вселенной': 'S',
#  'каждая': 'APRO',
#  'клетка': 'S',
#  'служит': 'V',
#  'какой-то': 'APRO',
#  'общей': 'A',
#  'цели': 'S',
#  'увидев': 'V',
#  'эту': 'APRO',
#  'модель': 'S',
#  'внутри': 'PR',
#  'нас': 'SPRO',
#  'самих': 'APRO',
#  'сами': 'APRO',
#  'научились': 'V',
#  'делать': 'V',
#  'нейросеть': 'S',
#  'создала': 'V',
#  'много': 'ADV',
#  'нейросетей': 'S',
#  'которые': 'APRO',
#  'сделали': 'V',
#  'Софья': 'S',
#  'Галевская': 'A',
#  'Друзья': 'S',
#  'Мне': 'SPRO',
#  'для': 'PR',
#  'одного': 'ANUM',
#  'проекта': 'S',
#  'нужны': 'A',
#  'люди': 'S',
#  'пользуясь': 'V',
#  'услугами': 'S',
#  'такси': 'S',
#  'столкнулись': 'V',
#  'глухонемым': 'A',
#  'водителем': 'S',
#  'Очень': 'ADV',
#  'ваши': 'APRO',
#  'мысли': 'S',
#  'какие-то': 'APRO',
#  'впечатления': 'S',
#  'от': 'PR',
#  'опыта': 'S',
#  'Прошу': 'V',
#  'репост': 'S',
#  'нечего': 'ADV',
#  'сказать': 'V',
#  'смотерть': 'S',
#  'Психоделичные': 'A',
#  'ролики': 'S',
#  'студии': 'S',
#  'отдельный': 'A',
#  'вид': 'S',
#  'искусства': 'S',
#  'Человекоподобные': 'A',
#  'чудовища': 'S',
#  'лишним': 'A',
#  'весом': 'S',
#  'Исковерканные': 'V',
#  'тела': 'S',
#  'проваливающиеся': 'V',
#  'бездну': 'S',
#  'Голые': 'A',
#  'мужчины': 'S',
#  'левитирующих': 'V',
#  'стульях': 'S',
#  'имитирующие': 'V',
#  'поведение': 'S',
#  'чаек': 'S',
#  'Эти': 'APRO',
#  'другие': 'APRO',
#  'пугающие': 'V',
#  'образы': 'S',
#  'были': 'V',
#  'порождены': 'V',
#  'фантазией': 'S',
#  'мастеров': 'S',
#  'видеоарта': 'S',
#  'Брайана': 'S',
#  'Тесслера': 'S',
#  'Джона': 'S',
#  'Бейкена': 'S',
#  'Изначально': 'ADV',
#  'под': 'PR',
#  'нарочито': 'ADV',
#  'бесхитростным': 'A',
#  'названием': 'S',
#  'они': 'SPRO',
#  'запустили': 'V',
#  'платформе': 'S',
#  'Постепенно': 'ADV',
#  'их': 'APRO',
#  'армия': 'S',
#  'монстров': 'S',
#  'захватывать': 'V',
#  'соцсети': 'S',
#  'очень': 'ADV',
#  'круто': 'ADV',
#  'всегда': 'ADVPRO',
#  'был': 'V',
#  'важен': 'A',
#  'вопрос': 'S',
#  'авторства': 'S',
#  'хоть': 'PART',
#  'особо': 'ADV',
#  'ничего': 'SPRO',
#  'не': 'PART',
#  'произвожу': 'V',
#  'возможно': 'ADV',
#  'стараюсь': 'V',
#  'указывать': 'V',
#  'авторов': 'S',
#  'потому': 'ADVPRO',
#  'произвести': 'V',
#  'контент': 'S',
#  'большой': 'A',
#  'труд': 'S',
#  'давайте': 'V',
#  'признаемся': 'V',
#  'любим': 'V',
#  'попсу': 'S',
#  'х': 'S',
#  'Аудиозапись': 'S',
#  'мая': 'S',
#  'недавно': 'ADV',
#  'наткнулась': 'V',
#  'песни': 'S',
#  'жанре': 'S',
#  'а': 'CONJ',
#  'капелла': 'S',
#  'раньше': 'ADV',
#  'обращала': 'V',
#  'внимания': 'S',
#  'Они': 'SPRO',
#  'понравились': 'V',
#  'похожи': 'A',
#  'жизнь': 'S',
#  'послушайте': 'V',
#  'начале': 'S',
#  'ждёшь': 'V',
#  'будет': 'V',
#  'дроп': 'S',
#  'уже': 'ADV',
#  'начнётся': 'V',
#  'движуха': 'S',
#  'Также': 'ADV',
#  'она': 'SPRO',
#  'идёт': 'V',
#  'ждать': 'V',
#  'какого-то': 'APRO',
#  'особенного': 'A',
#  'момента': 'S',
#  'пропустишь': 'V',
#  'Все': 'SPRO',
#  'понятия': 'S',
#  'психологии': 'S',
#  'эго': 'S',
#  'индивид': 'S',
#  'личность': 'S',
#  'проистекают': 'V',
#  'иллюзии': 'S',
#  'субстанциального': 'A',
#  'тождества': 'S',
#  'Но': 'CONJ',
#  'эта': 'APRO',
#  'иллюзия': 'S',
#  'восходит': 'V',
#  'основе': 'S',
#  'своей': 'APRO',
#  'суеверию': 'S',
#  'которое': 'APRO',
#  'обманывает': 'V',
#  'только': 'PART',
#  'здравый': 'A',
#  'смысл': 'S',
#  'также': 'ADV',
#  'философов': 'S',
#  'вере': 'S',
#  'язык': 'S',
#  'точнее': 'ADV',
#  'истинность': 'S',
#  'грамматических': 'A',
#  'категорий': 'S',
#  'Именно': 'PART',
#  'грамматика': 'S',
#  'структура': 'S',
#  'субъект': 'S',
#  'предикат': 'S',
#  'внушила': 'V',
#  'Декарту': 'S',
#  'уверенность': 'S',
#  'том': 'SPRO',
#  'является': 'V',
#  'субъектом': 'S',
#  'мышления': 'S',
#  'время': 'S',
#  'эти': 'APRO',
#  'скорее': 'ADV',
#  'приходят': 'V',
#  'ко': 'PR',
#  'основании': 'S',
#  'своём': 'APRO',
#  'вера': 'S',
#  'грамматические': 'A',
#  'структуры': 'S',
#  'выражает': 'V',
#  'волю': 'S',
#  'быть': 'V',
#  'причиной': 'S',
#  'своих': 'APRO',
#  'мыслей': 'S',
#  'Субъект': 'S',
#  'самость': 'S',
#  'являются': 'V',
#  'во': 'PR',
#  'многом': 'APRO',
#  'ложными': 'A',
#  'понятиями': 'S',
#  'поскольку': 'CONJ',
#  'трансформируют': 'V',
#  'фиктивные': 'A',
#  'единства': 'S',
#  'сущности': 'S',
#  'изначально': 'ADV',
#  'имеющие': 'V',
#  'языковую': 'A',
#  'реальность': 'S',
#  'Мишель': 'S',
#  'Хаар': 'S',
#  'может': 'V',
#  'тупо': 'ADV',
#  'беспокоюсь': 'V',
#  'людей': 'S',
#  'постят': 'V',
#  'лайкают': 'V',
#  'комментят': 'S',
#  'видите': 'V',
#  'высказываться': 'V',
#  'почему': 'ADVPRO',
#  'тут': 'ADVPRO',
#  'публичная': 'A',
#  'сфера': 'S',
#  'обмен': 'S',
#  'мнениями': 'S',
#  'опытом': 'S',
#  'конечно': 'ADV',
#  'осуждаю': 'V',
#  'принуждаю': 'V',
#  'посты': 'S',
#  'даже': 'PART',
#  'комменты': 'S',
#  'способ': 'S',
#  'коннекшена': 'S',
#  'интересно': 'ADV',
#  'других': 'APRO',
#  'происходит': 'V',
#  'вообще': 'ADV',
#  'Да': 'CONJ',
#  'приятно': 'ADV',
#  'ленте': 'S',
#  'видеть': 'V',
#  'пост': 'S',
#  'паблика': 'S',
#  'давно': 'ADV',
#  'мучаюсь': 'V',
#  'могу': 'V',
#  'определиться': 'V',
#  'провести': 'V',
#  'наш': 'APRO',
#  'однокурсницами': 'S',
#  'клуб': 'S',
#  'любителей': 'S',
#  'современного': 'A',
#  'сменил': 'V',
#  'формат': 'S',
#  'кроме': 'PR',
#  'совместных': 'A',
#  'бесплатных': 'A',
#  'походов': 'S',
#  'по': 'PR',
#  'выставкам': 'S',
#  'галереям': 'S',
#  'будем': 'V',
#  'публиковать': 'V',
#  'статьи': 'S',
#  'рецензии': 'S',
#  'подборки': 'S',
#  'чего': 'SPRO',
#  'полезного': 'A',
#  'НЕ': 'PART',
#  'БОЙСЯ': 'V',
#  'БОЙСА': 'S',
#  'Выбрали': 'V',
#  'вас': 'SPRO',
#  'несколько': 'ADV',
#  'самых': 'APRO',
#  'любимых': 'A',
#  'приложений': 'S',
#  'про': 'PR',
#  'искусство': 'S',
#  'чтобы': 'CONJ',
#  'сделать': 'V',
#  'его': 'APRO',
#  'ближе': 'ADV',
#  'Огромная': 'A',
#  'база': 'S',
#  'произведений': 'S',
#  'коллекций': 'S',
#  'музеев': 'S',
#  'всему': 'SPRO',
#  'миру': 'S',
#  'удобно': 'ADV',
#  'категоризированная': 'V',
#  'художникам': 'S',
#  'национальными': 'A',
#  'школам': 'S',
#  'стилевым': 'A',
#  'течениям': 'S',
#  'Можно': 'ADV',
#  'рассматривать': 'V',
#  'делиться': 'V',
#  'друзьями': 'S',
#  'скачивать': 'V',
#  'То': 'SPRO',
#  'приложение': 'S',
#  'помощью': 'S',
#  'которого': 'APRO',
#  'друзья': 'S',
#  'делали': 'V',
#  'коллажи': 'S',
#  'со': 'PR',
#  'своими': 'APRO',
#  'селфи': 'S',
#  'похожими': 'A',
#  'них': 'SPRO',
#  'персонажами': 'S',
#  'функционалу': 'S',
#  'напоминает': 'V',
#  'музеи': 'S',
#  'загрузить': 'V',
#  'фотографию': 'S',
#  'работы': 'S',
#  'оно': 'SPRO',
#  'даст': 'V',
#  'ее': 'SPRO',
#  'экспликацию': 'S',
#  'Несложные': 'A',
#  'тесты': 'S',
#  'разным': 'A',
#  'художественным': 'A',
#  'направлениям': 'S',
#  'могут': 'V',
#  'стать': 'V',
#  'приятным': 'A',
#  'вечерним': 'A',
#  'развлечением': 'S',
#  'послужить': 'V',
#  'подспорьем': 'S',
#  'подготовке': 'S',
#  'экзамену': 'S',
#  'теории': 'S',
#  'истории': 'S',
#  'ДАРАГАЯ': 'S',
#  'МАЯ': 'S',
#  'СИСТРРРР': 'S',
#  'наверно': 'ADV',
#  'актуально': 'ADV',
#  'писать': 'V',
#  'поздравление': 'S',
#  'стене': 'S',
#  'желаю': 'V',
#  'тебе': 'SPRO',
#  'успехов': 'S',
#  'экзаменах': 'S',
#  'улыбаайся': 'S',
#  'будь': 'V',
#  'счастлива': 'A',
#  'Лолла': 'S',
#  'Шаляпина': 'S',
#  'приправа': 'S',
#  'магги': 'S',
#  'котлет': 'S',
#  'фарша': 'S',
#  'попробую': 'V',
#  'сварить': 'V',
#  'макароны': 'S',
#  'вкусом': 'S',
#  'говорил': 'V',
#  'конфуций': 'S',
#  'чё': 'S',
#  'будешь': 'V',
#  'работать': 'V',
#  'ни': 'PART',
#  'дня': 'S',
#  'сложно': 'ADV',
#  'жить': 'V',
#  'тебя': 'SPRO',
#  'плохо': 'ADV',
#  'остальных': 'APRO',
#  'Поэтому': 'ADVPRO',
#  'спасает': 'V',
#  'чувства': 'S',
#  'отчуждённости': 'S',
#  'кажется': 'V',
#  'ты': 'SPRO',
#  'живёшь': 'V',
#  'какую-то': 'APRO',
#  'совершенно': 'ADV',
#  'другую': 'APRO',
#  'Так': 'ADVPRO',
#  'вместе': 'ADV',
#  'мной': 'SPRO',
#  'можете': 'V',
#  'шутить': 'V',
#  'проебываться': 'V',
#  'обижаться': 'V',
#  'мои': 'APRO',
#  'шутки': 'S',
#  'говорить': 'V',
#  'что-то': 'SPRO',
#  'обидное': 'A',
#  'опаздывать': 'V',
#  'непонятное': 'A',
#  'молчать': 'V',
#  'тоже': 'PART',
#  'делаю': 'V',
#  'наконец': 'ADV',
#  'посмотрела': 'V',
#  'тесноту': 'S',
#  'кантемира': 'S',
#  'балагова': 'S',
#  'Фильм': 'S',
#  'Нальчик': 'S',
#  'Кабардино-Балкария': 'S',
#  'евреев': 'S',
#  'общину': 'S',
#  'семью': 'S',
#  'личный': 'A',
#  'кризис': 'S',
#  'смотреть': 'V',
#  'было': 'V',
#  'тесно': 'ADV',
#  'крупняков': 'S',
#  'обрезанного': 'V',
#  'кадра': 'S',
#  'Даже': 'PART',
#  'смотря': 'ADV',
#  'финальной': 'A',
#  'сцене': 'S',
#  'водопад': 'S',
#  'шумит': 'V',
#  'нереалистично': 'A',
#  'тихо': 'ADV',
#  'советую': 'V',
#  'людям': 'S',
#  'берут': 'V',
#  'библиотеках': 'S',
#  'книжки': 'S',
#  'возвращают': 'V',
#  'ВАС': 'SPRO',
#  'апр': 'S',
#  'мутить': 'V',
#  'перф': 'S',
#  'защиту': 'S',
#  'ИНТЕРНЕТ': 'S',
#  'КАФЕ': 'S',
#  'мар': 'S',
#  'Журнал': 'S',
#  'Инициативная': 'A',
#  'группа': 'S',
#  'студентов': 'S',
#  'Факультета': 'S',
#  'коммуникаций': 'S',
#  'медиа': 'S',
#  'дизайна': 'S',
#  'написала': 'V',
#  'открытое': 'A',
#  'о': 'PR',
#  'ситуации': 'S',
#  'вокруг': 'PR',
#  'передачи': 'S',
#  'точку': 'S',
#  'пресс-секретарем': 'S',
#  'Президента': 'S',
#  'РФ': 'S',
#  'Дмитрием': 'S',
#  'Песковым': 'S',
#  'Студенты': 'S',
#  'возмущены': 'V',
#  'ситуация': 'S',
#  'отразилась': 'V',
#  'репутации': 'S',
#  'Вышки': 'S',
#  'считают': 'V',
#  'решение': 'S',
#  'запись': 'S',
#  'принятое': 'V',
#  'Факультетом': 'S',
#  'цензурой': 'S',
#  'Если': 'CONJ',
#  'студент': 'S',
#  'выпускник': 'S',
#  'добавить': 'V',
#  'подпись': 'S',
#  'письму': 'S',
#  'этой': 'APRO',
#  'форме': 'S',
#  'Про': 'PR',
#  'левых': 'A',
#  'правых': 'A',
#  'юлецобразовательный': 'A',
#  'Юля': 'S',
#  'Демидова': 'S',
#  'МиниТест': 'S',
#  'Какая': 'APRO',
#  'какашка': 'S',
#  'показал': 'V',
#  'результат': 'S',
#  'ниже': 'ADV',
#  'Много': 'ADV',
#  'тестов': 'S',
#  'здесь': 'ADVPRO',
#  'Софииишка': 'S',
#  'Ан': 'CONJ',
#  'буквы': 'S',
#  'обычно': 'ADV',
#  'Люди': 'S',
#  'редко': 'ADV',
#  'меняют': 'V',
#  'аватарки': 'S',
#  'счастливее': 'ADV',
#  'тех': 'APRO',
#  'делает': 'V',
#  'чаще': 'ADV',
#  'находятся': 'V',
#  'гармонии': 'S',
#  'собой': 'SPRO',
#  'идентичностью': 'S',
#  'Каждая': 'APRO',
#  'аватарка': 'S',
#  'ассоциируются': 'V',
#  'определенными': 'A',
#  'событиями': 'S',
#  'самоощущением': 'S',
#  'желание': 'S',
#  'поменять': 'V',
#  'её': 'SPRO',
#  'вызывается': 'V',
#  'чувством': 'S',
#  'дискомфорта': 'S',
#  'фотография': 'S',
#  'картинка': 'S',
#  'являться': 'V',
#  'знаком': 'S',
#  'твоей': 'APRO',
#  'личности': 'S',
#  'интернете': 'S',
#  'Те': 'APRO',
#  'часто': 'ADV',
#  'меняет': 'V',
#  'всего': 'PART',
#  'поисках': 'S',
#  'нельзя': 'ADV',
#  'такие': 'APRO',
#  'поиски': 'S',
#  'правило': 'S',
#  'связаны': 'A',
#  'тревожным': 'A',
#  'отсутствием': 'S',
#  'внутреннего': 'A',
#  'равновесия': 'S',
#  'Отсутствие': 'S',
#  'желания': 'S',
#  'поставить': 'V',
#  'новую': 'A',
#  'фотку': 'S',
#  'аву': 'S',
#  'без': 'PR',
#  'исключений': 'S',
#  'говорит': 'V',
#  'стабильности': 'S',
#  'знак': 'S',
#  'положительным': 'A',
#  'отрицательным': 'A',
#  'человек': 'S',
#  'равнодушен': 'A',
#  'аватарке': 'S',
#  'либо': 'CONJ',
#  'связь': 'S',
#  'между': 'PR',
#  'этим': 'SPRO',
#  'означающим': 'V',
#  'означаемым': 'V',
#  'личностью': 'S',
#  'вызывает': 'V',
#  'никакого': 'APRO',
#  'беспокойства': 'S',
#  'глубоко': 'ADV',
#  'разорвана': 'V',
#  'имеет': 'V',
#  'обажаю': 'S',
#  'знаю': 'V',
#  'фев': 'S',
#  'Что': 'SPRO',
#  'гуглят': 'V',
#  'голосом': 'S',
#  'господи': 'INTJ',
#  'спасибо': 'S',
#  'дюркгейма': 'S',
#  'знайте': 'V',
#  'википедии': 'S',
#  'такая': 'APRO',
#  'страница': 'S',
#  'случаев': 'S',
#  'россии': 'S',
#  'завидую': 'V',
#  'умеет': 'V',
#  'немецком': 'A',
#  'молодцы': 'S',
#  'долой': 'ADV',
#  'свободу': 'S',
#  'янв': 'S',
#  'Наталья': 'S',
#  'Нетребская': 'A',
#  'Иду': 'V',
#  'покупать': 'V',
#  'себе': 'SPRO',
#  'новенький': 'S',
#  'Айфон': 'S',
#  'рублей': 'S',
#  'Два': 'NUM',
#  'сюртука': 'S',
#  'один': 'ANUM',
#  'Двумя': 'NUM',
#  'сюртуками': 'S',
#  'одеть': 'V',
#  'двух': 'NUM',
#  'одним': 'APRO',
#  'К': 'PR',
#  'Маркс': 'S',
#  'Зима': 'S',
#  'морозный': 'A',
#  'ветерок': 'S',
#  'оставляет': 'V',
#  'румянец': 'S',
#  'щеках': 'S',
#  'московские': 'A',
#  'улицы': 'S',
#  'покрылись': 'V',
#  'пушистым': 'A',
#  'снежком': 'S',
#  'хрустит': 'V',
#  'ногами': 'S',
#  'БЕСИТ': 'V',
#  'НЕНАВИЖУ': 'V',
#  'ЗИМУ': 'S',
#  'И': 'CONJ',
#  'ЖАЛКИЕ': 'A',
#  'ПОПЫТКИ': 'S',
#  'НАЙТИ': 'V',
#  'НЕЙ': 'SPRO',
#  'КАКИЕ-ТО': 'APRO',
#  'ПЛЮСЫ': 'S',
#  'Определяем': 'V',
#  'тип': 'S',
#  'бизнеса': 'S',
#  'типу': 'S',
#  'лица': 'S',
#  'дебютировала': 'V',
#  'авторском': 'A',
#  'кино': 'S',
#  'Максим': 'S',
#  'Монталов': 'S',
#  'ненавижу': 'V',
#  'современный': 'A',
#  'русский': 'A',
#  'гламур': 'S',
#  'ж': 'PART',
#  'прожили': 'V',
#  'целых': 'A',
#  'лет': 'S',
#  'Сократа': 'S',
#  'новым': 'A',
#  'годом': 'S',
#  'вчерашний': 'A',
#  'вечер': 'S',
#  'должен': 'A',
#  'войти': 'V',
#  'историю': 'S',
#  'моя': 'APRO',
#  'преподавательница': 'S',
#  'похвалила': 'V',
#  'сториз': 'S',
#  'инстаграме': 'S',
#  'дек': 'S',
#  'эй': 'INTJ',
#  'пацан': 'S',
#  'О': 'S',
#  'теле': 'S',
#  'душе': 'S',
#  'страдать': 'V',
#  'приходится': 'V',
#  'будущая': 'A',
#  'профессия': 'S',
#  'самая': 'APRO',
#  'нужная': 'A',
#  'хлебная': 'A',
#  'россия': 'S',
#  'которую': 'APRO',
#  'потеряли': 'V',
#  'чудеса': 'S',
#  'рф': 'S',
#  'российские': 'A',
#  'звёзды': 'S',
#  'Уже': 'ADV',
#  'следующей': 'A',
#  'неделе': 'S',
#  'замечательная': 'A',
#  'Рита': 'S',
#  'Осепян': 'A',
#  'поведает': 'V',
#  'занимается': 'V',
#  'главный': 'A',
#  'куратор': 'S',
#  'галереи': 'S',
#  'Солянке': 'S',
#  'числе': 'S',
#  'работе': 'S',
#  'над': 'PR',
#  'выставкой': 'S',
#  'Бразилии': 'S',
#  'поделится': 'V',
#  'профессиональным': 'A',
#  'советы': 'S',
#  'хочет': 'V',
#  'создать': 'V',
#  'собственный': 'A',
#  'кураторский': 'A',
#  'Вам': 'SPRO',
#  'кураторство': 'S',
#  'знаете': 'V',
#  'начать': 'V',
#  'воплотить': 'V',
#  'свои': 'APRO',
#  'задумки': 'S',
#  'Хорошие': 'A',
#  'новости': 'S',
#  'тот': 'APRO',
#  'самый': 'APRO',
#  'которому': 'APRO',
#  'стоит': 'V',
#  ...}

# %%
len(story.split())
# Out:
# 2840

# %%
len(words_pos)
# Out:
# 1295

# %%
# Считаем абсолютную частоту частей речи.
# Надо создать новый словарь где ключом будет название части речи (значение из пред.слваря), а значением — его абс. частотность, которую мы считаем из предыдущего словаря

pos_abs_freq = {}
for k, v in words_pos.items():
    pos_abs_freq[v] = sum(value == v for value in words_pos.values()) 
    
pos_abs_freq
# Out:
# {'S': 2541,
#  'V': 1194,
#  'PR': 58,
#  'A': 783,
#  'SPRO': 93,
#  'APRO': 196,
#  'ADV': 292,
#  'ADVPRO': 43,
#  'CONJ': 42,
#  'PART': 43,
#  'NUM': 26,
#  'ANUM': 25,
#  'INTJ': 10,
#  'COM': 2}

# %%
# Считаем относительную частоту частей речи.


# Надо создать новый словарь где ключом будет название части речи (из абсолютного словаря, а значением — его относительная частотность 
# (т.е. делим абсолютную (значение) на длину текста в словах)
pos_rel_freq = {}
for k, v in pos_abs_freq.items():
    pos_rel_freq[k] = (v/len(story.split()))*1000000
    
pos_rel_freq
# Out:
# {'PR': 13028.169014084508,
#  'S': 154929.57746478872,
#  'V': 153521.12676056338,
#  'A': 35211.2676056338,
#  'ADV': 30633.80281690141,
#  'SPRO': 19014.08450704225,
#  'CONJ': 7042.2535211267605,
#  'PART': 9859.154929577466,
#  'ADVPRO': 8450.704225352112,
#  'APRO': 17957.74647887324,
#  'ANUM': 704.2253521126761,
#  'INTJ': 2464.7887323943664,
#  'NUM': 3169.0140845070423}
